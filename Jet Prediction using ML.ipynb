# %% [markdown]
# # Particle Classification using ML

# %% [markdown]
# ## In this notebook, we explore the MultiJet dataset from CMS using Machine Learning and Predict Jet Count

# %% [markdown]
# ### Description of the Dataset
# 1) Run: The run number of the event.
# 2) Lumi: The lumi section of the event.
# 3) Event: The event number of the event.
# 4) MR: First razor kinematic variable, the MR variable is an estimate of an overall mass scale, which in the limit of massless decay products equals the mass of the heavy parent particle.
# 5) Rsq: Second razor kinematic variable, the Rsq variable is the square of the ratio R, which quantifies the flow of energy in the plane perpendicular to the beam and the partitioning of momentum between visible and invisible particles.
# 6) E1
# 7) Px1
# 8) Py1
# 9) Pz1: The four-vector of the leading megajet (with the largest transverse momentum).
# 10) E2
# 11) Px2
# 12) Py2
# 13) Pz2: The four-vector of the subleading megajet (with the largest transverse momentum).
# 14) HT: The scalar sum of the transverse momentum of the jets.
# 15) MET: The magnitude of the vector sum of the transverse energy of the particles in the event.
# 16) nJets: The number of jets with transverse momentum above 40 GeV.
# 17) nBJets: The number of b-tagged jets with transverse momentum above 40 GeV.
#
#
# ### Acknowledgements
# Duarte, Javier; (2015). Example CSV output file for SUSYBSMAnalysis-RazorFilter. CERN Open Data Portal.

# %%
# imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
df = pd.read_csv('/Users/soumyashaw/Desktop/Masters Thesis/Particle Classification using ML/MultiJetRun2010B.csv')

# %%
df.head()
# Out:
#       Run  Lumi      Event       MR       Rsq        E1      Px1        Py1  \
# 0  148029   388  302318745  215.553  0.031977  136.7100 -109.893  -54.03420
# 1  148029   388  302323641  155.437  0.042157   83.3865   81.150    6.88361
# 2  148029   388  302336217  400.563  0.026938  253.1840  139.902  102.64000
# 3  148029   388  302382289  286.245  0.094192  175.4860 -156.024  -62.95350
# 4  148029   388  302403873  204.514  0.018804  833.7950  100.410  -16.65900
#
#         Pz1        E2       Px2       Py2       Pz2       HT       MET  nJets  \
# 0  -58.9032  142.1790   70.0254  41.12250 -116.5130  203.666  18.31100      2
# 1  -12.9688   73.9025  -72.2472  11.88350    3.0899  154.659  14.77470      2
# 2 -101.9350  535.5510 -110.3790 -89.09290 -516.1790  343.280  25.22110      3
# 3  -47.7434  112.8510   89.0843   3.45025   67.9007  257.397  46.02880      2
# 4 -827.4980  445.6120  -91.1991  15.55830 -390.1440  269.492   8.11345      3
#
#    nBJets
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ### Baseline Results
# #### - Linear Regression (66%)
# #### - K-Nearest Neighbors (66%)

# %%
# Import necessary libraries

features = list(df.columns)

df = df[df['nJets'] <= 4]  # we only need bi, tri and tetrajets

X = df[features].drop(columns=['nJets'])
y = df['nJets']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (important for KNN)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the Linear Regression model
modelLR = LinearRegression()
modelLR.fit(X_train, y_train)

# Create and train the KNN model
modelKNN  = KNeighborsClassifier(n_neighbors=5)
modelKNN.fit(X_train_scaled, y_train)

# Predict on test data (Linear Regression)
y_pred_LR = modelLR.predict(X_test)
y_pred_LR = np.round(y_pred_LR)

# Predict on test data (KNN)
y_pred_KNN = modelKNN.predict(X_test_scaled)

# Evaluation metrics for Linear Regression
print("Linear Regression:")
print(classification_report(y_test, y_pred_LR))

print("K-Nearest Neighbors:")
print(classification_report(y_test, y_pred_KNN))
# Out:
# Linear Regression:
#               precision    recall  f1-score   support
#
#          2.0       0.76      0.84      0.80      4233
#          3.0       0.43      0.41      0.42      1824
#          4.0       0.46      0.04      0.08       403
#          5.0       0.00      0.00      0.00         0
#          6.0       0.00      0.00      0.00         0
#
#     accuracy                           0.67      6460
#    macro avg       0.33      0.26      0.26      6460
# weighted avg       0.65      0.67      0.65      6460
#
# K-Nearest Neighbors:
#               precision    recall  f1-score   support
#
#            2       0.72      0.89      0.80      4233
#            3       0.45      0.29      0.35      1824
#            4       0.43      0.08      0.14       403
#
#     accuracy                           0.67      6460
#    macro avg       0.53      0.42      0.43      6460
# weighted avg       0.63      0.67      0.63      6460
# /opt/homebrew/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Data Preprocessing

# Drop unnecessary columns
df2 = df.drop(['Event', 'Run', 'Lumi'], axis=1)
print(df2.head())

# Correlation Matrix
corr = df2.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

sns.pairplot(df2, corner=True, plot_kws={'s': 10, 'alpha': 0.5})
plt.tight_layout()
plt.show()

df2 = df2[df2['nJets'] <= 4]  # we only need bi, tri and tetrajets

# Split the data into features and target
X = df2.drop('nJets', axis=1)
y = df2['nJets']

# Feature Scaling
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
#         MR       Rsq        E1      Px1        Py1       Pz1        E2  \
# 0  215.553  0.031977  136.7100 -109.893  -54.03420  -58.9032  142.1790
# 1  155.437  0.042157   83.3865   81.150    6.88361  -12.9688   73.9025
# 2  400.563  0.026938  253.1840  139.902  102.64000 -101.9350  535.5510
# 3  286.245  0.094192  175.4860 -156.024  -62.95350  -47.7434  112.8510
# 4  204.514  0.018804  833.7950  100.410  -16.65900 -827.4980  445.6120
#
#         Px2       Py2       Pz2       HT       MET  nJets  nBJets
# 0   70.0254  41.12250 -116.5130  203.666  18.31100      2       0
# 1  -72.2472  11.88350    3.0899  154.659  14.77470      2       0
# 2 -110.3790 -89.09290 -516.1790  343.280  25.22110      3       0
# 3   89.0843   3.45025   67.9007  257.397  46.02880      2       0
# 4  -91.1991  15.55830 -390.1440  269.492   8.11345      3       0

# %%
# PCA for Dimensionality Reduction
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95, svd_solver='full')
X_train_pca = pca.fit_transform(X_train)

X_test_pca = pca.transform(X_test)

# Step 4: Output the number of components and shape
print(f"Number of components selected: {pca.n_components_}")
print(f"Shape of PCA-transformed data: {X_train_pca.shape}")

print(X_train.shape)
print(X_train_pca.shape)
print(y_train.shape)
# Out:
# Number of components selected: 10
# Shape of PCA-transformed data: (15071, 10)
# (15071, 13)
# (15071, 10)
# (15071,)

# %% [markdown]
# ### Predict number of jets (`nJets`) from the other features.

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.71      0.92      0.81      4233
#            3       0.42      0.21      0.28      1824
#            4       0.37      0.06      0.10       403
#
#     accuracy                           0.67      6460
#    macro avg       0.50      0.40      0.40      6460
# weighted avg       0.61      0.67      0.61      6460

# %%
# K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=2)
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.73      0.93      0.81      4233
#            3       0.53      0.29      0.37      1824
#            4       0.53      0.08      0.13       403
#
#     accuracy                           0.69      6460
#    macro avg       0.59      0.43      0.44      6460
# weighted avg       0.66      0.69      0.65      6460

# %%
# SVM
from sklearn.svm import SVC

model = SVC(kernel='rbf', probability=True)
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.82      0.99      0.90      4233
#            3       0.76      0.53      0.62      1824
#            4       0.71      0.10      0.17       403
#
#     accuracy                           0.81      6460
#    macro avg       0.76      0.54      0.56      6460
# weighted avg       0.79      0.81      0.77      6460

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.79      0.77      0.78      4233
#            3       0.46      0.48      0.47      1824
#            4       0.24      0.25      0.25       403
#
#     accuracy                           0.66      6460
#    macro avg       0.50      0.50      0.50      6460
# weighted avg       0.66      0.66      0.66      6460

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.79      0.92      0.85      4233
#            3       0.58      0.45      0.51      1824
#            4       0.45      0.11      0.18       403
#
#     accuracy                           0.74      6460
#    macro avg       0.60      0.49      0.51      6460
# weighted avg       0.71      0.74      0.71      6460

# %%
# AdaBoost
from sklearn.ensemble import AdaBoostClassifier

model = AdaBoostClassifier(n_estimators=200)
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.82      0.88      0.85      4233
#            3       0.57      0.51      0.53      1824
#            4       0.46      0.29      0.36       403
#
#     accuracy                           0.74      6460
#    macro avg       0.62      0.56      0.58      6460
# weighted avg       0.72      0.74      0.73      6460

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.71      0.87      0.78      4233
#            3       0.39      0.17      0.24      1824
#            4       0.23      0.25      0.24       403
#
#     accuracy                           0.64      6460
#    macro avg       0.44      0.43      0.42      6460
# weighted avg       0.59      0.64      0.59      6460

# %%
# MLP Classifier
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300)
model.fit(X_train_pca, y_train)
y_pred = model.predict(X_test_pca)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.89      0.97      0.93      4233
#            3       0.78      0.67      0.72      1824
#            4       0.54      0.35      0.42       403
#
#     accuracy                           0.85      6460
#    macro avg       0.74      0.66      0.69      6460
# weighted avg       0.84      0.85      0.84      6460

# %%
# Deep Neural Network
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.layers as L

model = keras.Sequential()
model.add(L.Input(shape=10))
model.add(L.Dense(128))
model.add(L.ReLU())
model.add(L.Dense(64))
model.add(L.ReLU())
model.add(L.Dense(8))
model.add(L.Softmax())

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1408
#
#  re_lu (ReLU)                (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  re_lu_1 (ReLU)              (None, 64)                0
#
#  dense_2 (Dense)             (None, 8)                 520
#
#  softmax (Softmax)           (None, 8)                 0
#
# =================================================================
# Total params: 10184 (39.78 KB)
# Trainable params: 10184 (39.78 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer=keras.optimizers.RMSprop(),loss=keras.losses.SparseCategoricalCrossentropy(),metrics=keras.metrics.SparseCategoricalAccuracy())
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.RMSprop` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.RMSprop`.

# %%
model.fit(x=X_train_pca,y=y_train,epochs=100)
# Out:
# Epoch 1/100
# 471/471 [==============================] - 1s 548us/step - loss: 0.6839 - sparse_categorical_accuracy: 0.6842
# Epoch 2/100
# 471/471 [==============================] - 0s 534us/step - loss: 0.5587 - sparse_categorical_accuracy: 0.7470
# Epoch 3/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.4925 - sparse_categorical_accuracy: 0.7877
# Epoch 4/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.4553 - sparse_categorical_accuracy: 0.8034
# Epoch 5/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.4311 - sparse_categorical_accuracy: 0.8187
# Epoch 6/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.4179 - sparse_categorical_accuracy: 0.8248
# Epoch 7/100
# 471/471 [==============================] - 0s 532us/step - loss: 0.4071 - sparse_categorical_accuracy: 0.8284
# Epoch 8/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.3948 - sparse_categorical_accuracy: 0.8361
# Epoch 9/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.3875 - sparse_categorical_accuracy: 0.8370
# Epoch 10/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3835 - sparse_categorical_accuracy: 0.8399
# Epoch 11/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3789 - sparse_categorical_accuracy: 0.8417
# Epoch 12/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.3721 - sparse_categorical_accuracy: 0.8460
# Epoch 13/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3694 - sparse_categorical_accuracy: 0.8449
# Epoch 14/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.3660 - sparse_categorical_accuracy: 0.8475
# Epoch 15/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3609 - sparse_categorical_accuracy: 0.8508
# Epoch 16/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3563 - sparse_categorical_accuracy: 0.8503
# Epoch 17/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3530 - sparse_categorical_accuracy: 0.8524
# Epoch 18/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3545 - sparse_categorical_accuracy: 0.8512
# Epoch 19/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3490 - sparse_categorical_accuracy: 0.8543
# Epoch 20/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3454 - sparse_categorical_accuracy: 0.8542
# Epoch 21/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3429 - sparse_categorical_accuracy: 0.8588
# Epoch 22/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3411 - sparse_categorical_accuracy: 0.8599
# Epoch 23/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3389 - sparse_categorical_accuracy: 0.8582
# Epoch 24/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.3366 - sparse_categorical_accuracy: 0.8601
# Epoch 25/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3338 - sparse_categorical_accuracy: 0.8607
# Epoch 26/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3320 - sparse_categorical_accuracy: 0.8611
# Epoch 27/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.3270 - sparse_categorical_accuracy: 0.8625
# Epoch 28/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3249 - sparse_categorical_accuracy: 0.8631
# Epoch 29/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3235 - sparse_categorical_accuracy: 0.8644
# Epoch 30/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3191 - sparse_categorical_accuracy: 0.8678
# Epoch 31/100
# 471/471 [==============================] - 0s 623us/step - loss: 0.3202 - sparse_categorical_accuracy: 0.8692
# Epoch 32/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.3161 - sparse_categorical_accuracy: 0.8662
# Epoch 33/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3121 - sparse_categorical_accuracy: 0.8721
# Epoch 34/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.3126 - sparse_categorical_accuracy: 0.8696
# Epoch 35/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.3108 - sparse_categorical_accuracy: 0.8703
# Epoch 36/100
# 471/471 [==============================] - 0s 538us/step - loss: 0.3100 - sparse_categorical_accuracy: 0.8715
# Epoch 37/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.3057 - sparse_categorical_accuracy: 0.8725
# Epoch 38/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.3052 - sparse_categorical_accuracy: 0.8753
# Epoch 39/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.3015 - sparse_categorical_accuracy: 0.8733
# Epoch 40/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.3029 - sparse_categorical_accuracy: 0.8745
# Epoch 41/100
# 471/471 [==============================] - 0s 524us/step - loss: 0.3005 - sparse_categorical_accuracy: 0.8752
# Epoch 42/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2973 - sparse_categorical_accuracy: 0.8784
# Epoch 43/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2983 - sparse_categorical_accuracy: 0.8755
# Epoch 44/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.2949 - sparse_categorical_accuracy: 0.8788
# Epoch 45/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2948 - sparse_categorical_accuracy: 0.8765
# Epoch 46/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2963 - sparse_categorical_accuracy: 0.8768
# Epoch 47/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2925 - sparse_categorical_accuracy: 0.8806
# Epoch 48/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2880 - sparse_categorical_accuracy: 0.8816
# Epoch 49/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2880 - sparse_categorical_accuracy: 0.8798
# Epoch 50/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2890 - sparse_categorical_accuracy: 0.8785
# Epoch 51/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2843 - sparse_categorical_accuracy: 0.8830
# Epoch 52/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.2815 - sparse_categorical_accuracy: 0.8841
# Epoch 53/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2823 - sparse_categorical_accuracy: 0.8841
# Epoch 54/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2821 - sparse_categorical_accuracy: 0.8844
# Epoch 55/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2806 - sparse_categorical_accuracy: 0.8830
# Epoch 56/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2778 - sparse_categorical_accuracy: 0.8867
# Epoch 57/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2798 - sparse_categorical_accuracy: 0.8857
# Epoch 58/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2764 - sparse_categorical_accuracy: 0.8869
# Epoch 59/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2766 - sparse_categorical_accuracy: 0.8845
# Epoch 60/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2765 - sparse_categorical_accuracy: 0.8860
# Epoch 61/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2731 - sparse_categorical_accuracy: 0.8883
# Epoch 62/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2750 - sparse_categorical_accuracy: 0.8878
# Epoch 63/100
# 471/471 [==============================] - 0s 623us/step - loss: 0.2708 - sparse_categorical_accuracy: 0.8895
# Epoch 64/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2703 - sparse_categorical_accuracy: 0.8899
# Epoch 65/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2714 - sparse_categorical_accuracy: 0.8898
# Epoch 66/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2684 - sparse_categorical_accuracy: 0.8903
# Epoch 67/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2691 - sparse_categorical_accuracy: 0.8907
# Epoch 68/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2678 - sparse_categorical_accuracy: 0.8910
# Epoch 69/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2648 - sparse_categorical_accuracy: 0.8910
# Epoch 70/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2650 - sparse_categorical_accuracy: 0.8906
# Epoch 71/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2644 - sparse_categorical_accuracy: 0.8915
# Epoch 72/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2636 - sparse_categorical_accuracy: 0.8936
# Epoch 73/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2623 - sparse_categorical_accuracy: 0.8935
# Epoch 74/100
# 471/471 [==============================] - 0s 562us/step - loss: 0.2625 - sparse_categorical_accuracy: 0.8927
# Epoch 75/100
# 471/471 [==============================] - 0s 532us/step - loss: 0.2627 - sparse_categorical_accuracy: 0.8931
# Epoch 76/100
# 471/471 [==============================] - 0s 526us/step - loss: 0.2591 - sparse_categorical_accuracy: 0.8966
# Epoch 77/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2576 - sparse_categorical_accuracy: 0.8936
# Epoch 78/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2566 - sparse_categorical_accuracy: 0.8960
# Epoch 79/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2565 - sparse_categorical_accuracy: 0.8960
# Epoch 80/100
# 471/471 [==============================] - 0s 529us/step - loss: 0.2570 - sparse_categorical_accuracy: 0.8945
# Epoch 81/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2550 - sparse_categorical_accuracy: 0.8955
# Epoch 82/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2558 - sparse_categorical_accuracy: 0.8946
# Epoch 83/100
# 471/471 [==============================] - 0s 525us/step - loss: 0.2569 - sparse_categorical_accuracy: 0.8961
# Epoch 84/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2520 - sparse_categorical_accuracy: 0.8964
# Epoch 85/100
# 471/471 [==============================] - 0s 550us/step - loss: 0.2498 - sparse_categorical_accuracy: 0.8985
# Epoch 86/100
# 471/471 [==============================] - 0s 547us/step - loss: 0.2527 - sparse_categorical_accuracy: 0.9005
# Epoch 87/100
# 471/471 [==============================] - 0s 527us/step - loss: 0.2527 - sparse_categorical_accuracy: 0.8961
# Epoch 88/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2509 - sparse_categorical_accuracy: 0.8964
# Epoch 89/100
# 471/471 [==============================] - 0s 622us/step - loss: 0.2503 - sparse_categorical_accuracy: 0.8991
# Epoch 90/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2485 - sparse_categorical_accuracy: 0.8978
# Epoch 91/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.2463 - sparse_categorical_accuracy: 0.9001
# Epoch 92/100
# 471/471 [==============================] - 0s 524us/step - loss: 0.2478 - sparse_categorical_accuracy: 0.8998
# Epoch 93/100
# 471/471 [==============================] - 0s 593us/step - loss: 0.2452 - sparse_categorical_accuracy: 0.9018
# Epoch 94/100
# 471/471 [==============================] - 0s 582us/step - loss: 0.2481 - sparse_categorical_accuracy: 0.8983
# Epoch 95/100
# 471/471 [==============================] - 0s 609us/step - loss: 0.2454 - sparse_categorical_accuracy: 0.8983
# Epoch 96/100
# 471/471 [==============================] - 0s 549us/step - loss: 0.2441 - sparse_categorical_accuracy: 0.9005
# Epoch 97/100
# 471/471 [==============================] - 0s 533us/step - loss: 0.2445 - sparse_categorical_accuracy: 0.9034
# Epoch 98/100
# 471/471 [==============================] - 0s 531us/step - loss: 0.2427 - sparse_categorical_accuracy: 0.9031
# Epoch 99/100
# 471/471 [==============================] - 0s 530us/step - loss: 0.2433 - sparse_categorical_accuracy: 0.9027
# Epoch 100/100
# 471/471 [==============================] - 0s 528us/step - loss: 0.2436 - sparse_categorical_accuracy: 0.9026

# %%
preds = model.predict(X_test_pca)
prediction = np.argmax(preds,axis=1)
print(classification_report(y_test, prediction))
# Out:
# 202/202 [==============================] - 0s 389us/step
#               precision    recall  f1-score   support
#
#            2       0.94      0.89      0.91      4233
#            3       0.66      0.80      0.72      1824
#            4       0.46      0.26      0.33       403
#
#     accuracy                           0.83      6460
#    macro avg       0.69      0.65      0.66      6460
# weighted avg       0.83      0.83      0.82      6460

# %% [markdown]
# ## Final Evaluation Summary
#
# After evaluating multiple machine learning models on the CMS MultiJet dataset to predict jet counts (`nJets`), the following results were obtained:
#
# - **Baseline: Linear Regression**
#   - Accuracy: **67%**
#
# - **Baseline: K-Nearest Neighbors**
#   - Accuracy: **67%**
#
# - **Support Vector Machine**
#   - Accuracy: **81%**
#   - Good precision and recall for class `2` (F1: 0.90)
#   - Poor performance for class `4` (F1: 0.17)
#
# - **Random Forest**
#   - Accuracy: **74%**
#   - Improved performance on class `3` compared to KNN
#   - Still underperforming for class `4` (F1: 0.24)
#
# - **MLP Classifier**
#   - Accuracy: **86%**
#   - Best precision and recall for class `2` (F1: 0.93)
#   - Reasonable handling of class `3` (F1: 0.74)
#   - Class `4` remains underrepresented (F1: 0.37)
#
# - **Tensorflow Neural Network**
#   - Accuracy: **84%**
#   - Similar performance to MLP Classifier
#   - Class `4` still underrepresented (F1: 0.44)
#
# ### Key Takeaways:
# - Class `2` dominates predictions and is learned well by all models.
# - Models struggle to generalize for higher jet count classes (imbalanced data).
# - **MLP Classifier** consistently outperforms others in overall accuracy and weighted F1.
